# %% [markdown]
# A. Video Loading and Property Extraction
# OpenCV Video Capture:
# The code uses cv2.VideoCapture to open the original video file. The properties such as fps, total frame count, frame width, and height are obtained with cap.get() calls.
# Citation: OpenCV VideoCapture Documentation
#
# B. Frame Conversion
# Timestamps to Frame Indices:
# The timestamp (seconds) is multiplied by the fps to yield frame indices (e.g., start_frame = int(start_time * fps)). This conversion is standard in video processing.
#
# C. Ensuring Minimum Number of Frames
# Frame Deficit Handling:
# The code checks if the number of frames in the segment is fewer than 8. If so, it first attempts to extend the segment forward. If that is not sufficient (e.g., reaching the end of the video), it then extends backward. This ensures that each clip contains at least eight frames.
#
# D. Video Clipping and Writing
# Writing Video Clips:
# A loop extracts frames starting from the adjusted start_frame to end_frame and writes them into a new video file using cv2.VideoWriter.
# Citation: OpenCV VideoWriter Documentation
#
# E. CSV File Creation
# Mapping Video Path and Caption:
# The mapping is stored in a list and then written into a CSV file with pandas. This CSV serves as an index connecting each generated clip to its corresponding caption.
#
# 4. Useful Links and Citations
# OpenCV Documentation:
#
# Video Capture and Video Properties: OpenCV Documentation
#
# Video Writer: OpenCV VideoWriter Documentation
#
# Python JSON Library: Python JSON Docs
#
# pandas: pandas Documentation

# %%
import cv2
import json
import os
import math
import pandas as pd

# --- Configuration ---
json_path = "/kaggle/input/ucf-mini/normal_sampled_annotations.json"
videos_dir = "/kaggle/input/ucf-mini"
output_dir = "./splitted_clips_normal"
csv_output_path = "./splitted_clips_normal.csv"
min_frames = 8

# Create output directory if it does not exist
os.makedirs(output_dir, exist_ok=True)

# --- Load JSON Dataset ---
with open(json_path, "r") as f:
    dataset = json.load(f)

csv_rows = []

# --- Process Each Video in the Dataset ---
for video_name, video_data in dataset.items():
    video_file = os.path.join(videos_dir, video_name + ".mp4")  # Adjust the extension if necessary

    # Open video capture using OpenCV
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        print(f"Error opening video {video_file}")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # or use 'XVID' if you prefer

    # Process each segment: iterate over timestamps and corresponding caption
    for idx, (times, caption) in enumerate(zip(video_data["timestamps"], video_data["sentences"])):
        start_time, end_time = times
        start_frame = int(start_time * fps)
        end_frame = int(end_time * fps)
        num_frames = end_frame - start_frame

        # Adjust segment if less than minimum required frames
        if num_frames < min_frames:
            deficit = min_frames - num_frames

            # Try extending forward
            if end_frame + deficit <= total_frames:
                end_frame += deficit
            else:
                # If not enough frames ahead, try extending backward
                if start_frame - deficit >= 0:
                    start_frame -= deficit
                else:
                    # Fallback: use entire range if possible
                    start_frame = 0
                    end_frame = total_frames

            # Update num_frames based on new indices
            num_frames = end_frame - start_frame

        # Set the video to the starting frame
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

        # Prepare output clip file path and writer
        output_clip_path = os.path.join(f"{video_name}_clip{idx}.mp4")
        out = cv2.VideoWriter(output_clip_path, fourcc, fps, (width, height))

        # Write frames to the new clip
        frames_written = 0
        for f in range(start_frame, end_frame):
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)
            frames_written += 1
        out.release()

        print(f"Extracted clip: {output_clip_path} with {frames_written} frames.")

        # Append CSV mapping info: ensuring the caption is trimmed
        csv_rows.append({
            "video_path": output_clip_path,
            "caption": caption.strip()
        })

    # Reset cap to the beginning (or close and reopen for next video)
    cap.release()

# --- Save CSV Mapping ---
df = pd.DataFrame(csv_rows)
df.to_csv(csv_output_path, index=False)
print(f"CSV mapping saved to: {csv_output_path}")
# Out:
# Extracted clip: Normal_Videos615_x264_clip0.mp4 with 453 frames.
# Extracted clip: Normal_Videos615_x264_clip1.mp4 with 666 frames.
# Extracted clip: Normal_Videos615_x264_clip2.mp4 with 516 frames.
# Extracted clip: Normal_Videos615_x264_clip3.mp4 with 678 frames.
# Extracted clip: Normal_Videos615_x264_clip4.mp4 with 663 frames.
# Extracted clip: Normal_Videos615_x264_clip5.mp4 with 1164 frames.
# Extracted clip: Normal_Videos_944_x264_clip0.mp4 with 120 frames.
# Extracted clip: Normal_Videos_944_x264_clip1.mp4 with 120 frames.
# Extracted clip: Normal_Videos_944_x264_clip2.mp4 with 120 frames.
# Extracted clip: Normal_Videos_944_x264_clip3.mp4 with 120 frames.
# Extracted clip: Normal_Videos_944_x264_clip4.mp4 with 777 frames.
# Extracted clip: Normal_Videos_944_x264_clip5.mp4 with 180 frames.
# Extracted clip: Normal_Videos_944_x264_clip6.mp4 with 423 frames.
# Extracted clip: Normal_Videos_872_x264_clip0.mp4 with 210 frames.
# Extracted clip: Normal_Videos_872_x264_clip1.mp4 with 141 frames.
# Extracted clip: Normal_Videos112_x264_clip0.mp4 with 339 frames.
# Extracted clip: Normal_Videos112_x264_clip1.mp4 with 213 frames.
# Extracted clip: Normal_Videos112_x264_clip2.mp4 with 333 frames.
# Extracted clip: Normal_Videos112_x264_clip3.mp4 with 246 frames.
# Extracted clip: Normal_Videos862_x264_clip0.mp4 with 132 frames.
# Extracted clip: Normal_Videos862_x264_clip1.mp4 with 345 frames.
# Extracted clip: Normal_Videos862_x264_clip2.mp4 with 207 frames.
# Extracted clip: Normal_Videos862_x264_clip3.mp4 with 117 frames.
# Extracted clip: Normal_Videos862_x264_clip4.mp4 with 93 frames.
# Extracted clip: Normal_Videos328_x264_clip0.mp4 with 348 frames.
# Extracted clip: Normal_Videos328_x264_clip1.mp4 with 900 frames.
# Extracted clip: Normal_Videos806_x264_clip0.mp4 with 447 frames.
# Extracted clip: Normal_Videos806_x264_clip1.mp4 with 75 frames.
# Extracted clip: Normal_Videos806_x264_clip2.mp4 with 87 frames.
# Extracted clip: Normal_Videos806_x264_clip3.mp4 with 102 frames.
# Extracted clip: Normal_Videos806_x264_clip4.mp4 with 90 frames.
# Extracted clip: Normal_Videos806_x264_clip5.mp4 with 231 frames.
# Extracted clip: Normal_Videos806_x264_clip6.mp4 with 540 frames.
# Extracted clip: Normal_Videos806_x264_clip7.mp4 with 519 frames.
# Extracted clip: Normal_Videos_905_x264_clip0.mp4 with 51 frames.
# Extracted clip: Normal_Videos_905_x264_clip1.mp4 with 141 frames.
# Extracted clip: Normal_Videos_905_x264_clip2.mp4 with 84 frames.
# Extracted clip: Normal_Videos_905_x264_clip3.mp4 with 174 frames.
# Extracted clip: Normal_Videos789_x264_clip0.mp4 with 387 frames.
# Extracted clip: Normal_Videos789_x264_clip1.mp4 with 336 frames.
# Extracted clip: Normal_Videos789_x264_clip2.mp4 with 957 frames.
# Extracted clip: Normal_Videos789_x264_clip3.mp4 with 567 frames.
# Extracted clip: Normal_Videos789_x264_clip4.mp4 with 1059 frames.
# Extracted clip: Normal_Videos789_x264_clip5.mp4 with 1047 frames.
# Extracted clip: Normal_Videos789_x264_clip6.mp4 with 744 frames.
# Extracted clip: Normal_Videos_890_x264_clip0.mp4 with 75 frames.
# Extracted clip: Normal_Videos_890_x264_clip1.mp4 with 222 frames.
# Extracted clip: Normal_Videos_890_x264_clip2.mp4 with 126 frames.
# Extracted clip: Normal_Videos_890_x264_clip3.mp4 with 75 frames.
# Extracted clip: Normal_Videos_890_x264_clip4.mp4 with 75 frames.
# Extracted clip: Normal_Videos_890_x264_clip5.mp4 with 120 frames.
# Extracted clip: Normal_Videos_890_x264_clip6.mp4 with 300 frames.
# Extracted clip: Normal_Videos_890_x264_clip7.mp4 with 90 frames.
# Extracted clip: Normal_Videos_890_x264_clip8.mp4 with 150 frames.
# Extracted clip: Normal_Videos_890_x264_clip9.mp4 with 348 frames.
# Extracted clip: Normal_Videos_890_x264_clip10.mp4 with 300 frames.
# Extracted clip: Normal_Videos_890_x264_clip11.mp4 with 300 frames.
# Extracted clip: Normal_Videos_890_x264_clip12.mp4 with 300 frames.
# Extracted clip: Normal_Videos682_x264_clip0.mp4 with 465 frames.
# Extracted clip: Normal_Videos682_x264_clip1.mp4 with 309 frames.
# Extracted clip: Normal_Videos682_x264_clip2.mp4 with 192 frames.
# Extracted clip: Normal_Videos682_x264_clip3.mp4 with 162 frames.
# Extracted clip: Normal_Videos682_x264_clip4.mp4 with 222 frames.
# Extracted clip: Normal_Videos682_x264_clip5.mp4 with 357 frames.
# Extracted clip: Normal_Videos682_x264_clip6.mp4 with 558 frames.
# Extracted clip: Normal_Videos682_x264_clip7.mp4 with 354 frames.
# Extracted clip: Normal_Videos682_x264_clip8.mp4 with 474 frames.
# Extracted clip: Normal_Videos682_x264_clip9.mp4 with 495 frames.
# Extracted clip: Normal_Videos682_x264_clip10.mp4 with 354 frames.
# Extracted clip: Normal_Videos682_x264_clip11.mp4 with 528 frames.
# Extracted clip: Normal_Videos682_x264_clip12.mp4 with 417 frames.
# Extracted clip: Normal_Videos682_x264_clip13.mp4 with 375 frames.
# Extracted clip: Normal_Videos682_x264_clip14.mp4 with 399 frames.
# Extracted clip: Normal_Videos682_x264_clip15.mp4 with 378 frames.
# Extracted clip: Normal_Videos682_x264_clip16.mp4 with 264 frames.
# Extracted clip: Normal_Videos125_x264_clip0.mp4 with 117 frames.
# Extracted clip: Normal_Videos125_x264_clip1.mp4 with 177 frames.
# Extracted clip: Normal_Videos125_x264_clip2.mp4 with 27 frames.
# Extracted clip: Normal_Videos125_x264_clip3.mp4 with 363 frames.
# Extracted clip: Normal_Videos125_x264_clip4.mp4 with 150 frames.
# Extracted clip: Normal_Videos125_x264_clip5.mp4 with 183 frames.
# Extracted clip: Normal_Videos125_x264_clip6.mp4 with 780 frames.
# Extracted clip: Normal_Videos125_x264_clip7.mp4 with 339 frames.
# Extracted clip: Normal_Videos125_x264_clip8.mp4 with 210 frames.
# Extracted clip: Normal_Videos125_x264_clip9.mp4 with 210 frames.
# Extracted clip: Normal_Videos125_x264_clip10.mp4 with 96 frames.
# Extracted clip: Normal_Videos125_x264_clip11.mp4 with 66 frames.
# Extracted clip: Normal_Videos_365_x264_clip0.mp4 with 1899 frames.
# Extracted clip: Normal_Videos_365_x264_clip1.mp4 with 4959 frames.
# Extracted clip: Normal_Videos_365_x264_clip2.mp4 with 3879 frames.
# Extracted clip: Normal_Videos_365_x264_clip3.mp4 with 1245 frames.
# Extracted clip: Normal_Videos_365_x264_clip4.mp4 with 135 frames.
# Extracted clip: Normal_Videos_365_x264_clip5.mp4 with 1029 frames.
# Extracted clip: Normal_Videos_365_x264_clip6.mp4 with 1629 frames.
# Extracted clip: Normal_Videos942_x264_clip0.mp4 with 720 frames.
# Extracted clip: Normal_Videos942_x264_clip1.mp4 with 420 frames.
# Extracted clip: Normal_Videos942_x264_clip2.mp4 with 210 frames.
# Extracted clip: Normal_Videos_933_x264_clip0.mp4 with 90 frames.
# Extracted clip: Normal_Videos_933_x264_clip1.mp4 with 210 frames.
# Extracted clip: Normal_Videos_933_x264_clip2.mp4 with 240 frames.
# Extracted clip: Normal_Videos747_x264_clip0.mp4 with 780 frames.
# Extracted clip: Normal_Videos747_x264_clip1.mp4 with 870 frames.
# Extracted clip: Normal_Videos747_x264_clip2.mp4 with 705 frames.
# Extracted clip: Normal_Videos035_x264_clip0.mp4 with 96 frames.
# Extracted clip: Normal_Videos035_x264_clip1.mp4 with 630 frames.
# Extracted clip: Normal_Videos035_x264_clip2.mp4 with 486 frames.
# Extracted clip: Normal_Videos035_x264_clip3.mp4 with 900 frames.
# Extracted clip: Normal_Videos035_x264_clip4.mp4 with 1974 frames.
# Extracted clip: Normal_Videos035_x264_clip5.mp4 with 564 frames.
# Extracted clip: Normal_Videos035_x264_clip6.mp4 with 486 frames.
# Extracted clip: Normal_Videos035_x264_clip7.mp4 with 840 frames.
# Extracted clip: Normal_Videos035_x264_clip8.mp4 with 240 frames.
# Extracted clip: Normal_Videos035_x264_clip9.mp4 with 252 frames.
# Extracted clip: Normal_Videos035_x264_clip10.mp4 with 336 frames.
# Extracted clip: Normal_Videos035_x264_clip11.mp4 with 288 frames.
# Extracted clip: Normal_Videos035_x264_clip12.mp4 with 444 frames.
# Extracted clip: Normal_Videos035_x264_clip13.mp4 with 180 frames.
# Extracted clip: Normal_Videos035_x264_clip14.mp4 with 1071 frames.
# Extracted clip: Normal_Videos035_x264_clip15.mp4 with 1605 frames.
# Extracted clip: Normal_Videos035_x264_clip16.mp4 with 375 frames.
# Extracted clip: Normal_Videos035_x264_clip17.mp4 with 621 frames.
# Extracted clip: Normal_Videos035_x264_clip18.mp4 with 138 frames.
# Extracted clip: Normal_Videos035_x264_clip19.mp4 with 390 frames.
# Extracted clip: Normal_Videos035_x264_clip20.mp4 with 1893 frames.
# Extracted clip: Normal_Videos035_x264_clip21.mp4 with 645 frames.
# Extracted clip: Normal_Videos035_x264_clip22.mp4 with 2100 frames.
# Extracted clip: Normal_Videos035_x264_clip23.mp4 with 123 frames.
# Extracted clip: Normal_Videos035_x264_clip24.mp4 with 423 frames.
# Extracted clip: Normal_Videos035_x264_clip25.mp4 with 1257 frames.
# Extracted clip: Normal_Videos035_x264_clip26.mp4 with 567 frames.
# Extracted clip: Normal_Videos035_x264_clip27.mp4 with 777 frames.
# Extracted clip: Normal_Videos_070_x264_clip0.mp4 with 99 frames.
# Extracted clip: Normal_Videos_070_x264_clip1.mp4 with 51 frames.
# Extracted clip: Normal_Videos_070_x264_clip2.mp4 with 51 frames.
# Extracted clip: Normal_Videos_070_x264_clip3.mp4 with 261 frames.
# Extracted clip: Normal_Videos_070_x264_clip4.mp4 with 201 frames.
# Extracted clip: Normal_Videos_070_x264_clip5.mp4 with 201 frames.
# Extracted clip: Normal_Videos_070_x264_clip6.mp4 with 285 frames.
# Extracted clip: Normal_Videos_914_x264_clip0.mp4 with 141 frames.
# Extracted clip: Normal_Videos_914_x264_clip1.mp4 with 300 frames.
# Extracted clip: Normal_Videos_878_x264_clip0.mp4 with 220 frames.
# Extracted clip: Normal_Videos419_x264_clip0.mp4 with 330 frames.
# Extracted clip: Normal_Videos419_x264_clip1.mp4 with 333 frames.
# Extracted clip: Normal_Videos419_x264_clip2.mp4 with 345 frames.
# Extracted clip: Normal_Videos419_x264_clip3.mp4 with 276 frames.
# Extracted clip: Normal_Videos419_x264_clip4.mp4 with 303 frames.
# Extracted clip: Normal_Videos419_x264_clip5.mp4 with 24 frames.
# Extracted clip: Normal_Videos419_x264_clip6.mp4 with 138 frames.
# Extracted clip: Normal_Videos419_x264_clip7.mp4 with 90 frames.
# Extracted clip: Normal_Videos419_x264_clip8.mp4 with 120 frames.
# Extracted clip: Normal_Videos061_x264_clip0.mp4 with 2949 frames.
# Extracted clip: Normal_Videos061_x264_clip1.mp4 with 150 frames.
# Extracted clip: Normal_Videos061_x264_clip2.mp4 with 180 frames.
# Extracted clip: Normal_Videos061_x264_clip3.mp4 with 3276 frames.
# Extracted clip: Normal_Videos061_x264_clip4.mp4 with 587 frames.
# Extracted clip: Normal_Videos061_x264_clip5.mp4 with 303 frames.
# Extracted clip: Normal_Videos061_x264_clip6.mp4 with 246 frames.
# Extracted clip: Normal_Videos061_x264_clip7.mp4 with 420 frames.
# Extracted clip: Normal_Videos061_x264_clip8.mp4 with 243 frames.
# Extracted clip: Normal_Videos061_x264_clip9.mp4 with 366 frames.
# Extracted clip: Normal_Videos061_x264_clip10.mp4 with 534 frames.
# Extracted clip: Normal_Videos061_x264_clip11.mp4 with 264 frames.
# Extracted clip: Normal_Videos061_x264_clip12.mp4 with 1287 frames.
# Extracted clip: Normal_Videos061_x264_clip13.mp4 with 780 frames.
# Extracted clip: Normal_Videos061_x264_clip14.mp4 with 300 frames.
# Extracted clip: Normal_Videos061_x264_clip15.mp4 with 480 frames.
# Extracted clip: Normal_Videos061_x264_clip16.mp4 with 183 frames.
# Extracted clip: Normal_Videos061_x264_clip17.mp4 with 600 frames.
# Extracted clip: Normal_Videos061_x264_clip18.mp4 with 693 frames.
# Extracted clip: Normal_Videos061_x264_clip19.mp4 with 300 frames.
# Extracted clip: Normal_Videos061_x264_clip20.mp4 with 123 frames.
# Extracted clip: Normal_Videos061_x264_clip21.mp4 with 516 frames.
# Extracted clip: Normal_Videos061_x264_clip22.mp4 with 87 frames.
# Extracted clip: Normal_Videos061_x264_clip23.mp4 with 150 frames.
# Extracted clip: Normal_Videos061_x264_clip24.mp4 with 240 frames.
# Extracted clip: Normal_Videos061_x264_clip25.mp4 with 299 frames.
# Extracted clip: Normal_Videos061_x264_clip26.mp4 with 330 frames.
# Extracted clip: Normal_Videos061_x264_clip27.mp4 with 178 frames.
# Extracted clip: Normal_Videos590_x264_clip0.mp4 with 480 frames.
# Extracted clip: Normal_Videos590_x264_clip1.mp4 with 525 frames.
# Extracted clip: Normal_Videos590_x264_clip2.mp4 with 492 frames.
# Extracted clip: Normal_Videos590_x264_clip3.mp4 with 444 frames.
# Extracted clip: Normal_Videos590_x264_clip4.mp4 with 147 frames.
# Extracted clip: Normal_Videos590_x264_clip5.mp4 with 357 frames.
# Extracted clip: Normal_Videos590_x264_clip6.mp4 with 900 frames.
# Extracted clip: Normal_Videos590_x264_clip7.mp4 with 360 frames.
# Extracted clip: Normal_Videos590_x264_clip8.mp4 with 1050 frames.
# Extracted clip: Normal_Videos590_x264_clip9.mp4 with 126 frames.
# Extracted clip: Normal_Videos590_x264_clip10.mp4 with 96 frames.
# Extracted clip: Normal_Videos590_x264_clip11.mp4 with 150 frames.
# Extracted clip: Normal_Videos590_x264_clip12.mp4 with 81 frames.
# Extracted clip: Normal_Videos590_x264_clip13.mp4 with 1041 frames.
# Extracted clip: Normal_Videos590_x264_clip14.mp4 with 366 frames.
# Extracted clip: Normal_Videos590_x264_clip15.mp4 with 507 frames.
# Extracted clip: Normal_Videos590_x264_clip16.mp4 with 2130 frames.
# Extracted clip: Normal_Videos232_x264_clip0.mp4 with 783 frames.
# Extracted clip: Normal_Videos232_x264_clip1.mp4 with 660 frames.
# Extracted clip: Normal_Videos_877_x264_clip0.mp4 with 60 frames.
# Extracted clip: Normal_Videos_877_x264_clip1.mp4 with 60 frames.
# Extracted clip: Normal_Videos_877_x264_clip2.mp4 with 60 frames.
# Extracted clip: Normal_Videos_877_x264_clip3.mp4 with 60 frames.
# Extracted clip: Normal_Videos_877_x264_clip4.mp4 with 69 frames.
# Extracted clip: Normal_Videos_877_x264_clip5.mp4 with 312 frames.
# Extracted clip: Normal_Videos_877_x264_clip6.mp4 with 312 frames.
# Extracted clip: Normal_Videos_877_x264_clip7.mp4 with 150 frames.
# Extracted clip: Normal_Videos_877_x264_clip8.mp4 with 102 frames.
# Extracted clip: Normal_Videos_877_x264_clip9.mp4 with 102 frames.
# Extracted clip: Normal_Videos_877_x264_clip10.mp4 with 180 frames.
# Extracted clip: Normal_Videos_877_x264_clip11.mp4 with 300 frames.
# Extracted clip: Normal_Videos_877_x264_clip12.mp4 with 300 frames.
# Extracted clip: Normal_Videos_877_x264_clip13.mp4 with 60 frames.
# Extracted clip: Normal_Videos_877_x264_clip14.mp4 with 180 frames.
# Extracted clip: Normal_Videos_877_x264_clip15.mp4 with 180 frames.
# Extracted clip: Normal_Videos_877_x264_clip16.mp4 with 90 frames.
# Extracted clip: Normal_Videos_877_x264_clip17.mp4 with 120 frames.
# Extracted clip: Normal_Videos_877_x264_clip18.mp4 with 300 frames.
# Extracted clip: Normal_Videos_877_x264_clip19.mp4 with 120 frames.
# Extracted clip: Normal_Videos_877_x264_clip20.mp4 with 123 frames.
# Extracted clip: Normal_Videos_877_x264_clip21.mp4 with 120 frames.
# Extracted clip: Normal_Videos_877_x264_clip22.mp4 with 90 frames.
# Extracted clip: Normal_Videos131_x264_clip0.mp4 with 306 frames.
# Extracted clip: Normal_Videos131_x264_clip1.mp4 with 354 frames.
# Extracted clip: Normal_Videos131_x264_clip2.mp4 with 189 frames.
# Extracted clip: Normal_Videos131_x264_clip3.mp4 with 336 frames.
# Extracted clip: Normal_Videos131_x264_clip4.mp4 with 321 frames.
# Extracted clip: Normal_Videos131_x264_clip5.mp4 with 207 frames.
# Extracted clip: Normal_Videos184_x264_clip0.mp4 with 126 frames.
# Extracted clip: Normal_Videos184_x264_clip1.mp4 with 573 frames.
# Extracted clip: Normal_Videos184_x264_clip2.mp4 with 237 frames.
# Extracted clip: Normal_Videos184_x264_clip3.mp4 with 207 frames.
# Extracted clip: Normal_Videos184_x264_clip4.mp4 with 174 frames.
# Extracted clip: Normal_Videos184_x264_clip5.mp4 with 423 frames.
# Extracted clip: Normal_Videos749_x264_clip0.mp4 with 762 frames.
# Extracted clip: Normal_Videos095_x264_clip0.mp4 with 252 frames.
# Extracted clip: Normal_Videos095_x264_clip1.mp4 with 252 frames.
# Extracted clip: Normal_Videos095_x264_clip2.mp4 with 171 frames.
# Extracted clip: Normal_Videos095_x264_clip3.mp4 with 252 frames.
# Extracted clip: Normal_Videos095_x264_clip4.mp4 with 111 frames.
# Extracted clip: Normal_Videos095_x264_clip5.mp4 with 192 frames.
# Extracted clip: Normal_Videos095_x264_clip6.mp4 with 198 frames.
# Extracted clip: Normal_Videos095_x264_clip7.mp4 with 33 frames.
# Extracted clip: Normal_Videos560_x264_clip0.mp4 with 93 frames.
# Extracted clip: Normal_Videos560_x264_clip1.mp4 with 36 frames.
# Extracted clip: Normal_Videos560_x264_clip2.mp4 with 54 frames.
# Extracted clip: Normal_Videos560_x264_clip3.mp4 with 2392 frames.
# Extracted clip: Normal_Videos560_x264_clip4.mp4 with 330 frames.
# Extracted clip: Normal_Videos560_x264_clip5.mp4 with 55 frames.
# Extracted clip: Normal_Videos560_x264_clip6.mp4 with 51 frames.
# Extracted clip: Normal_Videos560_x264_clip7.mp4 with 120 frames.
# Extracted clip: Normal_Videos560_x264_clip8.mp4 with 5583 frames.
# Extracted clip: Normal_Videos560_x264_clip9.mp4 with 51 frames.
# Extracted clip: Normal_Videos560_x264_clip10.mp4 with 39 frames.
# Extracted clip: Normal_Videos560_x264_clip11.mp4 with 66 frames.
# Extracted clip: Normal_Videos560_x264_clip12.mp4 with 219 frames.
# Extracted clip: Normal_Videos560_x264_clip13.mp4 with 24 frames.
# Extracted clip: Normal_Videos560_x264_clip14.mp4 with 30 frames.
# Extracted clip: Normal_Videos560_x264_clip15.mp4 with 120 frames.
# Extracted clip: Normal_Videos560_x264_clip16.mp4 with 33 frames.
# Extracted clip: Normal_Videos560_x264_clip17.mp4 with 93 frames.
# Extracted clip: Normal_Videos560_x264_clip18.mp4 with 60 frames.
# Extracted clip: Normal_Videos560_x264_clip19.mp4 with 57 frames.
# Extracted clip: Normal_Videos423_x264_clip0.mp4 with 543 frames.
# Extracted clip: Normal_Videos423_x264_clip1.mp4 with 435 frames.
# Extracted clip: Normal_Videos423_x264_clip2.mp4 with 186 frames.
# Extracted clip: Normal_Videos423_x264_clip3.mp4 with 3324 frames.
# Extracted clip: Normal_Videos423_x264_clip4.mp4 with 808 frames.
# Extracted clip: Normal_Videos423_x264_clip5.mp4 with 510 frames.
# Extracted clip: Normal_Videos423_x264_clip6.mp4 with 207 frames.
# Extracted clip: Normal_Videos077_x264_clip0.mp4 with 51 frames.
# Extracted clip: Normal_Videos077_x264_clip1.mp4 with 393 frames.
# Extracted clip: Normal_Videos077_x264_clip2.mp4 with 423 frames.
# Extracted clip: Normal_Videos077_x264_clip3.mp4 with 270 frames.
# Extracted clip: Normal_Videos077_x264_clip4.mp4 with 270 frames.
# Extracted clip: Normal_Videos077_x264_clip5.mp4 with 300 frames.
# Extracted clip: Normal_Videos077_x264_clip6.mp4 with 453 frames.
# Extracted clip: Normal_Videos077_x264_clip7.mp4 with 60 frames.
# Extracted clip: Normal_Videos057_x264_clip0.mp4 with 549 frames.
# Extracted clip: Normal_Videos057_x264_clip1.mp4 with 414 frames.
# Extracted clip: Normal_Videos057_x264_clip2.mp4 with 438 frames.
# Extracted clip: Normal_Videos057_x264_clip3.mp4 with 1014 frames.
# Extracted clip: Normal_Videos057_x264_clip4.mp4 with 183 frames.
# Extracted clip: Normal_Videos057_x264_clip5.mp4 with 1223 frames.
# Extracted clip: Normal_Videos484_x264_clip0.mp4 with 270 frames.
# Extracted clip: Normal_Videos484_x264_clip1.mp4 with 840 frames.
# Extracted clip: Normal_Videos484_x264_clip2.mp4 with 300 frames.
# Extracted clip: Normal_Videos484_x264_clip3.mp4 with 1173 frames.
# Extracted clip: Normal_Videos484_x264_clip4.mp4 with 267 frames.
# Extracted clip: Normal_Videos484_x264_clip5.mp4 with 993 frames.
# Extracted clip: Normal_Videos484_x264_clip6.mp4 with 1647 frames.
# Extracted clip: Normal_Videos484_x264_clip7.mp4 with 927 frames.
# Extracted clip: Normal_Videos484_x264_clip8.mp4 with 1113 frames.
# Extracted clip: Normal_Videos484_x264_clip9.mp4 with 1467 frames.
# Extracted clip: Normal_Videos484_x264_clip10.mp4 with 1593 frames.
# Extracted clip: Normal_Videos484_x264_clip11.mp4 with 1590 frames.
# Extracted clip: Normal_Videos484_x264_clip12.mp4 with 1467 frames.
# Extracted clip: Normal_Videos484_x264_clip13.mp4 with 18510 frames.
# Extracted clip: Normal_Videos484_x264_clip14.mp4 with 990 frames.
# Extracted clip: Normal_Videos484_x264_clip15.mp4 with 1440 frames.
# Extracted clip: Normal_Videos484_x264_clip16.mp4 with 753 frames.
# Extracted clip: Normal_Videos484_x264_clip17.mp4 with 447 frames.
# Extracted clip: Normal_Videos484_x264_clip18.mp4 with 1383 frames.
# Extracted clip: Normal_Videos484_x264_clip19.mp4 with 837 frames.
# Extracted clip: Normal_Videos484_x264_clip20.mp4 with 1623 frames.
# Extracted clip: Normal_Videos484_x264_clip21.mp4 with 2427 frames.
# Extracted clip: Normal_Videos484_x264_clip22.mp4 with 483 frames.
# Extracted clip: Normal_Videos484_x264_clip23.mp4 with 477 frames.
# Extracted clip: Normal_Videos484_x264_clip24.mp4 with 2433 frames.
# Extracted clip: Normal_Videos484_x264_clip25.mp4 with 393 frames.
# Extracted clip: Normal_Videos484_x264_clip26.mp4 with 1197 frames.
# Extracted clip: Normal_Videos484_x264_clip27.mp4 with 417 frames.
# Extracted clip: Normal_Videos484_x264_clip28.mp4 with 1443 frames.
# Extracted clip: Normal_Videos484_x264_clip29.mp4 with 870 frames.
# Extracted clip: Normal_Videos484_x264_clip30.mp4 with 897 frames.
# Extracted clip: Normal_Videos484_x264_clip31.mp4 with 360 frames.
# Extracted clip: Normal_Videos484_x264_clip32.mp4 with 752 frames.
# Extracted clip: Normal_Videos484_x264_clip33.mp4 with 688 frames.
# Extracted clip: Normal_Videos484_x264_clip34.mp4 with 1443 frames.
# Extracted clip: Normal_Videos484_x264_clip35.mp4 with 747 frames.
# Extracted clip: Normal_Videos484_x264_clip36.mp4 with 600 frames.
# Extracted clip: Normal_Videos761_x264_clip0.mp4 with 2220 frames.
# Extracted clip: Normal_Videos761_x264_clip1.mp4 with 957 frames.
# Extracted clip: Normal_Videos547_x264_clip0.mp4 with 756 frames.
# Extracted clip: Normal_Videos547_x264_clip1.mp4 with 84 frames.
# Extracted clip: Normal_Videos547_x264_clip2.mp4 with 162 frames.
# Extracted clip: Normal_Videos547_x264_clip3.mp4 with 240 frames.
# Extracted clip: Normal_Videos547_x264_clip4.mp4 with 159 frames.
# Extracted clip: Normal_Videos547_x264_clip5.mp4 with 84 frames.
# Extracted clip: Normal_Videos547_x264_clip6.mp4 with 168 frames.
# Extracted clip: Normal_Videos547_x264_clip7.mp4 with 297 frames.
# Extracted clip: Normal_Videos547_x264_clip8.mp4 with 564 frames.
# Extracted clip: Normal_Videos547_x264_clip9.mp4 with 333 frames.
# Extracted clip: Normal_Videos547_x264_clip10.mp4 with 276 frames.
# Extracted clip: Normal_Videos547_x264_clip11.mp4 with 993 frames.
# Extracted clip: Normal_Videos547_x264_clip12.mp4 with 387 frames.
# Extracted clip: Normal_Videos547_x264_clip13.mp4 with 276 frames.
# Extracted clip: Normal_Videos547_x264_clip14.mp4 with 420 frames.
# Extracted clip: Normal_Videos547_x264_clip15.mp4 with 246 frames.
# Extracted clip: Normal_Videos547_x264_clip16.mp4 with 483 frames.
# Extracted clip: Normal_Videos547_x264_clip17.mp4 with 180 frames.
# Extracted clip: Normal_Videos547_x264_clip18.mp4 with 357 frames.
# Extracted clip: Normal_Videos547_x264_clip19.mp4 with 993 frames.
# Extracted clip: Normal_Videos547_x264_clip20.mp4 with 453 frames.
# Extracted clip: Normal_Videos547_x264_clip21.mp4 with 234 frames.
# Extracted clip: Normal_Videos547_x264_clip22.mp4 with 771 frames.
# Extracted clip: Normal_Videos547_x264_clip23.mp4 with 171 frames.
# Extracted clip: Normal_Videos547_x264_clip24.mp4 with 966 frames.
# Extracted clip: Normal_Videos547_x264_clip25.mp4 with 48 frames.
# Extracted clip: Normal_Videos547_x264_clip26.mp4 with 969 frames.
# Extracted clip: Normal_Videos547_x264_clip27.mp4 with 768 frames.
# Extracted clip: Normal_Videos547_x264_clip28.mp4 with 27 frames.
# Extracted clip: Normal_Videos547_x264_clip29.mp4 with 1110 frames.
# Extracted clip: Normal_Videos547_x264_clip30.mp4 with 237 frames.
# Extracted clip: Normal_Videos547_x264_clip31.mp4 with 120 frames.
# Extracted clip: Normal_Videos547_x264_clip32.mp4 with 666 frames.
# Extracted clip: Normal_Videos547_x264_clip33.mp4 with 3093 frames.
# Extracted clip: Normal_Videos547_x264_clip34.mp4 with 207 frames.
# Extracted clip: Normal_Videos547_x264_clip35.mp4 with 504 frames.
# Extracted clip: Normal_Videos547_x264_clip36.mp4 with 543 frames.
# Extracted clip: Normal_Videos547_x264_clip37.mp4 with 741 frames.
# Extracted clip: Normal_Videos547_x264_clip38.mp4 with 240 frames.
# Extracted clip: Normal_Videos547_x264_clip39.mp4 with 810 frames.
# Extracted clip: Normal_Videos547_x264_clip40.mp4 with 873 frames.
# Extracted clip: Normal_Videos547_x264_clip41.mp4 with 90 frames.
# Extracted clip: Normal_Videos547_x264_clip42.mp4 with 630 frames.
# Extracted clip: Normal_Videos547_x264_clip43.mp4 with 1169 frames.
# Extracted clip: Normal_Videos547_x264_clip44.mp4 with 537 frames.
# Extracted clip: Normal_Videos547_x264_clip45.mp4 with 186 frames.
# Extracted clip: Normal_Videos547_x264_clip46.mp4 with 1176 frames.
# Extracted clip: Normal_Videos547_x264_clip47.mp4 with 450 frames.
# Extracted clip: Normal_Videos547_x264_clip48.mp4 with 1026 frames.
# Extracted clip: Normal_Videos547_x264_clip49.mp4 with 324 frames.
# Extracted clip: Normal_Videos547_x264_clip50.mp4 with 1701 frames.
# Extracted clip: Normal_Videos547_x264_clip51.mp4 with 180 frames.
# Extracted clip: Normal_Videos547_x264_clip52.mp4 with 111 frames.
# Extracted clip: Normal_Videos547_x264_clip53.mp4 with 645 frames.
# Extracted clip: Normal_Videos547_x264_clip54.mp4 with 108 frames.
# Extracted clip: Normal_Videos547_x264_clip55.mp4 with 657 frames.
# Extracted clip: Normal_Videos547_x264_clip56.mp4 with 273 frames.
# Extracted clip: Normal_Videos547_x264_clip57.mp4 with 726 frames.
# Extracted clip: Normal_Videos547_x264_clip58.mp4 with 636 frames.
# Extracted clip: Normal_Videos547_x264_clip59.mp4 with 348 frames.
# Extracted clip: Normal_Videos547_x264_clip60.mp4 with 870 frames.
# Extracted clip: Normal_Videos547_x264_clip61.mp4 with 510 frames.
# Extracted clip: Normal_Videos547_x264_clip62.mp4 with 156 frames.
# Extracted clip: Normal_Videos547_x264_clip63.mp4 with 240 frames.
# Extracted clip: Normal_Videos547_x264_clip64.mp4 with 186 frames.
# Extracted clip: Normal_Videos547_x264_clip65.mp4 with 216 frames.
# Extracted clip: Normal_Videos547_x264_clip66.mp4 with 276 frames.
# Extracted clip: Normal_Videos547_x264_clip67.mp4 with 210 frames.
# Extracted clip: Normal_Videos547_x264_clip68.mp4 with 624 frames.
# Extracted clip: Normal_Videos547_x264_clip69.mp4 with 270 frames.
# Extracted clip: Normal_Videos547_x264_clip70.mp4 with 627 frames.
# Extracted clip: Normal_Videos547_x264_clip71.mp4 with 228 frames.
# Extracted clip: Normal_Videos547_x264_clip72.mp4 with 294 frames.
# Extracted clip: Normal_Videos547_x264_clip73.mp4 with 96 frames.
# Extracted clip: Normal_Videos547_x264_clip74.mp4 with 177 frames.
# Extracted clip: Normal_Videos547_x264_clip75.mp4 with 1203 frames.
# Extracted clip: Normal_Videos547_x264_clip76.mp4 with 126 frames.
# Extracted clip: Normal_Videos547_x264_clip77.mp4 with 63 frames.
# Extracted clip: Normal_Videos547_x264_clip78.mp4 with 177 frames.
# Extracted clip: Normal_Videos547_x264_clip79.mp4 with 453 frames.
# Extracted clip: Normal_Videos547_x264_clip80.mp4 with 591 frames.
# Extracted clip: Normal_Videos547_x264_clip81.mp4 with 123 frames.
# Extracted clip: Normal_Videos547_x264_clip82.mp4 with 663 frames.
# Extracted clip: Normal_Videos547_x264_clip83.mp4 with 690 frames.
# Extracted clip: Normal_Videos547_x264_clip84.mp4 with 486 frames.
# Extracted clip: Normal_Videos547_x264_clip85.mp4 with 561 frames.
# Extracted clip: Normal_Videos547_x264_clip86.mp4 with 198 frames.
# Extracted clip: Normal_Videos547_x264_clip87.mp4 with 390 frames.
# Extracted clip: Normal_Videos547_x264_clip88.mp4 with 688 frames.
# Extracted clip: Normal_Videos547_x264_clip89.mp4 with 178 frames.
# Extracted clip: Normal_Videos547_x264_clip90.mp4 with 729 frames.
# Extracted clip: Normal_Videos547_x264_clip91.mp4 with 305 frames.
# Extracted clip: Normal_Videos547_x264_clip92.mp4 with 120 frames.
# Extracted clip: Normal_Videos547_x264_clip93.mp4 with 120 frames.
# Extracted clip: Normal_Videos547_x264_clip94.mp4 with 63 frames.
# Extracted clip: Normal_Videos547_x264_clip95.mp4 with 204 frames.
# Extracted clip: Normal_Videos547_x264_clip96.mp4 with 90 frames.
# Extracted clip: Normal_Videos547_x264_clip97.mp4 with 597 frames.
# Extracted clip: Normal_Videos547_x264_clip98.mp4 with 1257 frames.
# Extracted clip: Normal_Videos547_x264_clip99.mp4 with 744 frames.
# Extracted clip: Normal_Videos547_x264_clip100.mp4 with 663 frames.
# Extracted clip: Normal_Videos547_x264_clip101.mp4 with 1686 frames.
# Extracted clip: Normal_Videos547_x264_clip102.mp4 with 423 frames.
# Extracted clip: Normal_Videos547_x264_clip103.mp4 with 486 frames.
# Extracted clip: Normal_Videos547_x264_clip104.mp4 with 174 frames.
# Extracted clip: Normal_Videos547_x264_clip105.mp4 with 1074 frames.
# Extracted clip: Normal_Videos547_x264_clip106.mp4 with 1080 frames.
# Extracted clip: Normal_Videos547_x264_clip107.mp4 with 489 frames.
# Extracted clip: Normal_Videos547_x264_clip108.mp4 with 210 frames.
# Extracted clip: Normal_Videos547_x264_clip109.mp4 with 360 frames.
# Extracted clip: Normal_Videos547_x264_clip110.mp4 with 1170 frames.
# Extracted clip: Normal_Videos547_x264_clip111.mp4 with 756 frames.
# Extracted clip: Normal_Videos547_x264_clip112.mp4 with 2742 frames.
# Extracted clip: Normal_Videos547_x264_clip113.mp4 with 249 frames.
# Extracted clip: Normal_Videos547_x264_clip114.mp4 with 234 frames.
# Extracted clip: Normal_Videos547_x264_clip115.mp4 with 543 frames.
# Extracted clip: Normal_Videos547_x264_clip116.mp4 with 570 frames.
# Extracted clip: Normal_Videos547_x264_clip117.mp4 with 2043 frames.
# Extracted clip: Normal_Videos547_x264_clip118.mp4 with 393 frames.
# Extracted clip: Normal_Videos547_x264_clip119.mp4 with 135 frames.
# Extracted clip: Normal_Videos547_x264_clip120.mp4 with 675 frames.
# Extracted clip: Normal_Videos547_x264_clip121.mp4 with 456 frames.
# Extracted clip: Normal_Videos547_x264_clip122.mp4 with 837 frames.
# Extracted clip: Normal_Videos547_x264_clip123.mp4 with 1866 frames.
# Extracted clip: Normal_Videos547_x264_clip124.mp4 with 717 frames.
# Extracted clip: Normal_Videos547_x264_clip125.mp4 with 207 frames.
# Extracted clip: Normal_Videos547_x264_clip126.mp4 with 477 frames.
# Extracted clip: Normal_Videos547_x264_clip127.mp4 with 1980 frames.
# Extracted clip: Normal_Videos547_x264_clip128.mp4 with 174 frames.
# Extracted clip: Normal_Videos547_x264_clip129.mp4 with 114 frames.
# Extracted clip: Normal_Videos547_x264_clip130.mp4 with 153 frames.
# Extracted clip: Normal_Videos547_x264_clip131.mp4 with 156 frames.
# Extracted clip: Normal_Videos547_x264_clip132.mp4 with 210 frames.
# Extracted clip: Normal_Videos547_x264_clip133.mp4 with 1044 frames.
# Extracted clip: Normal_Videos547_x264_clip134.mp4 with 384 frames.
# Extracted clip: Normal_Videos547_x264_clip135.mp4 with 63 frames.
# Extracted clip: Normal_Videos547_x264_clip136.mp4 with 156 frames.
# Extracted clip: Normal_Videos547_x264_clip137.mp4 with 144 frames.
# Extracted clip: Normal_Videos547_x264_clip138.mp4 with 210 frames.
# Extracted clip: Normal_Videos547_x264_clip139.mp4 with 147 frames.
# Extracted clip: Normal_Videos547_x264_clip140.mp4 with 123 frames.
# Extracted clip: Normal_Videos547_x264_clip141.mp4 with 210 frames.
# Extracted clip: Normal_Videos547_x264_clip142.mp4 with 141 frames.
# Extracted clip: Normal_Videos547_x264_clip143.mp4 with 1410 frames.
# Extracted clip: Normal_Videos547_x264_clip144.mp4 with 213 frames.
# Extracted clip: Normal_Videos547_x264_clip145.mp4 with 123 frames.
# Extracted clip: Normal_Videos547_x264_clip146.mp4 with 366 frames.
# Extracted clip: Normal_Videos547_x264_clip147.mp4 with 1104 frames.
# Extracted clip: Normal_Videos547_x264_clip148.mp4 with 120 frames.
# Extracted clip: Normal_Videos547_x264_clip149.mp4 with 210 frames.
# Extracted clip: Normal_Videos547_x264_clip150.mp4 with 849 frames.
# Extracted clip: Normal_Videos547_x264_clip151.mp4 with 240 frames.
# Extracted clip: Normal_Videos547_x264_clip152.mp4 with 333 frames.
# Extracted clip: Normal_Videos547_x264_clip153.mp4 with 657 frames.
# Extracted clip: Normal_Videos547_x264_clip154.mp4 with 1713 frames.
# Extracted clip: Normal_Videos547_x264_clip155.mp4 with 957 frames.
# Extracted clip: Normal_Videos547_x264_clip156.mp4 with 333 frames.
# Extracted clip: Normal_Videos547_x264_clip157.mp4 with 372 frames.
# Extracted clip: Normal_Videos547_x264_clip158.mp4 with 402 frames.
# Extracted clip: Normal_Videos547_x264_clip159.mp4 with 132 frames.
# Extracted clip: Normal_Videos547_x264_clip160.mp4 with 300 frames.
# Extracted clip: Normal_Videos547_x264_clip161.mp4 with 1116 frames.
# Extracted clip: Normal_Videos547_x264_clip162.mp4 with 393 frames.
# Extracted clip: Normal_Videos547_x264_clip163.mp4 with 93 frames.
# Extracted clip: Normal_Videos547_x264_clip164.mp4 with 300 frames.
# Extracted clip: Normal_Videos547_x264_clip165.mp4 with 90 frames.
# Extracted clip: Normal_Videos547_x264_clip166.mp4 with 63 frames.
# Extracted clip: Normal_Videos547_x264_clip167.mp4 with 753 frames.
# Extracted clip: Normal_Videos547_x264_clip168.mp4 with 174 frames.
# Extracted clip: Normal_Videos547_x264_clip169.mp4 with 117 frames.
# Extracted clip: Normal_Videos547_x264_clip170.mp4 with 330 frames.
# Extracted clip: Normal_Videos547_x264_clip171.mp4 with 756 frames.
# Extracted clip: Normal_Videos547_x264_clip172.mp4 with 300 frames.
# Extracted clip: Normal_Videos547_x264_clip173.mp4 with 1284 frames.
# Extracted clip: Normal_Videos547_x264_clip174.mp4 with 960 frames.
# Extracted clip: Normal_Videos547_x264_clip175.mp4 with 171 frames.
# Extracted clip: Normal_Videos547_x264_clip176.mp4 with 690 frames.
# Extracted clip: Normal_Videos547_x264_clip177.mp4 with 881 frames.
# Extracted clip: Normal_Videos547_x264_clip178.mp4 with 1972 frames.
# Extracted clip: Normal_Videos547_x264_clip179.mp4 with 1527 frames.
# Extracted clip: Normal_Videos547_x264_clip180.mp4 with 1119 frames.
# Extracted clip: Normal_Videos547_x264_clip181.mp4 with 870 frames.
# Extracted clip: Normal_Videos547_x264_clip182.mp4 with 1131 frames.
# Extracted clip: Normal_Videos547_x264_clip183.mp4 with 1206 frames.
# Extracted clip: Normal_Videos547_x264_clip184.mp4 with 1164 frames.
# Extracted clip: Normal_Videos547_x264_clip185.mp4 with 1200 frames.
# Extracted clip: Normal_Videos547_x264_clip186.mp4 with 2496 frames.
# Extracted clip: Normal_Videos547_x264_clip187.mp4 with 2154 frames.
# Extracted clip: Normal_Videos547_x264_clip188.mp4 with 1053 frames.
# Extracted clip: Normal_Videos547_x264_clip189.mp4 with 1770 frames.
# Extracted clip: Normal_Videos547_x264_clip190.mp4 with 1356 frames.
# Extracted clip: Normal_Videos547_x264_clip191.mp4 with 648 frames.
# Extracted clip: Normal_Videos547_x264_clip192.mp4 with 2343 frames.
# Extracted clip: Normal_Videos547_x264_clip193.mp4 with 1179 frames.
# Extracted clip: Normal_Videos547_x264_clip194.mp4 with 1068 frames.
# Extracted clip: Normal_Videos547_x264_clip195.mp4 with 2895 frames.
# Extracted clip: Normal_Videos547_x264_clip196.mp4 with 624 frames.
# Extracted clip: Normal_Videos547_x264_clip197.mp4 with 1221 frames.
# Extracted clip: Normal_Videos547_x264_clip198.mp4 with 903 frames.
# Extracted clip: Normal_Videos547_x264_clip199.mp4 with 1107 frames.
# Extracted clip: Normal_Videos547_x264_clip200.mp4 with 1002 frames.
# Extracted clip: Normal_Videos547_x264_clip201.mp4 with 924 frames.
# Extracted clip: Normal_Videos547_x264_clip202.mp4 with 1047 frames.
# Extracted clip: Normal_Videos547_x264_clip203.mp4 with 1146 frames.
# Extracted clip: Normal_Videos547_x264_clip204.mp4 with 1131 frames.
# Extracted clip: Normal_Videos547_x264_clip205.mp4 with 1275 frames.
# Extracted clip: Normal_Videos547_x264_clip206.mp4 with 795 frames.
# Extracted clip: Normal_Videos547_x264_clip207.mp4 with 930 frames.
# Extracted clip: Normal_Videos547_x264_clip208.mp4 with 819 frames.
# Extracted clip: Normal_Videos547_x264_clip209.mp4 with 1917 frames.
# Extracted clip: Normal_Videos257_x264_clip0.mp4 with 1380 frames.
# Extracted clip: Normal_Videos257_x264_clip1.mp4 with 576 frames.
# Extracted clip: Normal_Videos257_x264_clip2.mp4 with 532 frames.
# Extracted clip: Normal_Videos272_x264_clip0.mp4 with 453 frames.
# Extracted clip: Normal_Videos272_x264_clip1.mp4 with 630 frames.
# Extracted clip: Normal_Videos272_x264_clip2.mp4 with 153 frames.
# Extracted clip: Normal_Videos272_x264_clip3.mp4 with 693 frames.
# Extracted clip: Normal_Videos272_x264_clip4.mp4 with 840 frames.
# Extracted clip: Normal_Videos856_x264_clip0.mp4 with 528 frames.
# Extracted clip: Normal_Videos856_x264_clip1.mp4 with 405 frames.
# Extracted clip: Normal_Videos856_x264_clip2.mp4 with 180 frames.
# Extracted clip: Normal_Videos856_x264_clip3.mp4 with 33 frames.
# Extracted clip: Normal_Videos856_x264_clip4.mp4 with 294 frames.
# Extracted clip: Normal_Videos856_x264_clip5.mp4 with 531 frames.
# Extracted clip: Normal_Videos856_x264_clip6.mp4 with 717 frames.
# Extracted clip: Normal_Videos856_x264_clip7.mp4 with 600 frames.
# Extracted clip: Normal_Videos856_x264_clip8.mp4 with 90 frames.
# Extracted clip: Normal_Videos856_x264_clip9.mp4 with 237 frames.
# Extracted clip: Normal_Videos856_x264_clip10.mp4 with 156 frames.
# Extracted clip: Normal_Videos856_x264_clip11.mp4 with 60 frames.
# Extracted clip: Normal_Videos856_x264_clip12.mp4 with 123 frames.
# Extracted clip: Normal_Videos856_x264_clip13.mp4 with 189 frames.
# Extracted clip: Normal_Videos856_x264_clip14.mp4 with 918 frames.
# Extracted clip: Normal_Videos856_x264_clip15.mp4 with 405 frames.
# Extracted clip: Normal_Videos856_x264_clip16.mp4 with 45 frames.
# Extracted clip: Normal_Videos856_x264_clip17.mp4 with 297 frames.
# Extracted clip: Normal_Videos856_x264_clip18.mp4 with 471 frames.
# Extracted clip: Normal_Videos856_x264_clip19.mp4 with 855 frames.
# Extracted clip: Normal_Videos856_x264_clip20.mp4 with 531 frames.
# Extracted clip: Normal_Videos856_x264_clip21.mp4 with 207 frames.
# Extracted clip: Normal_Videos856_x264_clip22.mp4 with 300 frames.
# Extracted clip: Normal_Videos856_x264_clip23.mp4 with 387 frames.
# Extracted clip: Normal_Videos856_x264_clip24.mp4 with 804 frames.
# Extracted clip: Normal_Videos856_x264_clip25.mp4 with 201 frames.
# Extracted clip: Normal_Videos856_x264_clip26.mp4 with 213 frames.
# Extracted clip: Normal_Videos856_x264_clip27.mp4 with 60 frames.
# Extracted clip: Normal_Videos856_x264_clip28.mp4 with 483 frames.
# Extracted clip: Normal_Videos856_x264_clip29.mp4 with 39 frames.
# Extracted clip: Normal_Videos856_x264_clip30.mp4 with 687 frames.
# Extracted clip: Normal_Videos856_x264_clip31.mp4 with 96 frames.
# Extracted clip: Normal_Videos856_x264_clip32.mp4 with 90 frames.
# Extracted clip: Normal_Videos086_x264_clip0.mp4 with 156 frames.
# Extracted clip: Normal_Videos086_x264_clip1.mp4 with 495 frames.
# Extracted clip: Normal_Videos086_x264_clip2.mp4 with 255 frames.
# Extracted clip: Normal_Videos086_x264_clip3.mp4 with 537 frames.
# Extracted clip: Normal_Videos086_x264_clip4.mp4 with 345 frames.
# Extracted clip: Normal_Videos086_x264_clip5.mp4 with 741 frames.
# Extracted clip: Normal_Videos086_x264_clip6.mp4 with 861 frames.
# Extracted clip: Normal_Videos295_x264_clip0.mp4 with 363 frames.
# Extracted clip: Normal_Videos295_x264_clip1.mp4 with 234 frames.
# Extracted clip: Normal_Videos295_x264_clip2.mp4 with 90 frames.
# Extracted clip: Normal_Videos327_x264_clip0.mp4 with 1050 frames.
# Extracted clip: Normal_Videos327_x264_clip1.mp4 with 153 frames.
# Extracted clip: Normal_Videos327_x264_clip2.mp4 with 960 frames.
# Extracted clip: Normal_Videos327_x264_clip3.mp4 with 810 frames.
# Extracted clip: Normal_Videos178_x264_clip0.mp4 with 63 frames.
# Extracted clip: Normal_Videos178_x264_clip1.mp4 with 234 frames.
# Extracted clip: Normal_Videos178_x264_clip2.mp4 with 114 frames.
# Extracted clip: Normal_Videos178_x264_clip3.mp4 with 540 frames.
# Extracted clip: Normal_Videos842_x264_clip0.mp4 with 906 frames.
# Extracted clip: Normal_Videos040_x264_clip0.mp4 with 126 frames.
# Extracted clip: Normal_Videos040_x264_clip1.mp4 with 183 frames.
# Extracted clip: Normal_Videos040_x264_clip2.mp4 with 330 frames.
# Extracted clip: Normal_Videos040_x264_clip3.mp4 with 219 frames.
# Extracted clip: Normal_Videos040_x264_clip4.mp4 with 83 frames.
# Extracted clip: Normal_Videos504_x264_clip0.mp4 with 540 frames.
# Extracted clip: Normal_Videos_906_x264_clip0.mp4 with 120 frames.
# Extracted clip: Normal_Videos_906_x264_clip1.mp4 with 216 frames.
# Extracted clip: Normal_Videos_906_x264_clip2.mp4 with 63 frames.
# Extracted clip: Normal_Videos_906_x264_clip3.mp4 with 90 frames.
# Extracted clip: Normal_Videos948_x264_clip0.mp4 with 501 frames.
# Extracted clip: Normal_Videos948_x264_clip1.mp4 with 252 frames.
# Extracted clip: Normal_Videos948_x264_clip2.mp4 with 492 frames.
# Extracted clip: Normal_Videos948_x264_clip3.mp4 with 1260 frames.
# Extracted clip: Normal_Videos948_x264_clip4.mp4 with 780 frames.
# Extracted clip: Normal_Videos_050_x264_clip0.mp4 with 375 frames.
# Extracted clip: Normal_Videos_050_x264_clip1.mp4 with 375 frames.
# Extracted clip: Normal_Videos_050_x264_clip2.mp4 with 432 frames.
# Extracted clip: Normal_Videos_050_x264_clip3.mp4 with 432 frames.
# Extracted clip: Normal_Videos_050_x264_clip4.mp4 with 315 frames.
# Extracted clip: Normal_Videos_050_x264_clip5.mp4 with 132 frames.
# Extracted clip: Normal_Videos_050_x264_clip6.mp4 with 138 frames.
# Extracted clip: Normal_Videos_050_x264_clip7.mp4 with 303 frames.
# Extracted clip: Normal_Videos_050_x264_clip8.mp4 with 303 frames.
# Extracted clip: Normal_Videos_050_x264_clip9.mp4 with 243 frames.
# CSV mapping saved to: ./splitted_clips_normal.csv

# %%
# --- Save CSV Mapping ---
df = pd.DataFrame(csv_rows)
df.to_csv("/kaggle/working/splitted_clips_normal/splitted_clips_normal.csv", index=False)

# %%
import json
import os

# Save kaggle.json in ~/.kaggle/
with open('/kaggle/working/kaggle.json', 'w') as f:
    json.dump({"username":"nourfakih","key":"0005ac45aa3dc353c01a5d486ed0a5ac"}, f)

os.environ['KAGGLE_CONFIG_DIR'] = "/kaggle/working"

# !mkdir -p ~/.kaggle
# !cp /kaggle/working/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import os
dataset_name = "splitted-clips-normal"

# os.makedirs('/kaggle/working/' + dataset_name, exist_ok=True)

# # Move the folder inside the dataset directory
# shutil.move("/kaggle/working/UCF-mini-dataset/sampled_annotations.json", "/kaggle/working/UCF-mini-dataset/{dataset_name}")

# Create the metadata file
metadata = f"""
{{
  "title": "{dataset_name}",
  "id": "nourfakih/{dataset_name}",
  "licenses": [{{"name": "CC0-1.0"}}]
}}
"""

with open("/kaggle/working/splitted_clips_normal/dataset-metadata.json", "w") as f:
    f.write(metadata)

# %%
# !kaggle datasets create -p /kaggle/working/splitted_clips_normal
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /kaggle/working/kaggle.json'
# Starting upload for file splitted_clips_normal.csv
# 100%|██████████████████████████████████████| 84.3k/84.3k [00:00<00:00, 97.5kB/s]
# Upload successful: splitted_clips_normal.csv (84KB)
# Dataset creation error: The requested title "splitted-clips-normal" is already in use by a dataset. Please choose another title.
