# %% [markdown]
# #**NoteBook Summary**
#
# This notebook processes the UCF-Crime annotated video dataset to create a new dataset of timestamp-aligned image-caption pairs. It begins by loading JSON annotations for training, validation, and test splits, then matches each video key to its corresponding file. For each annotated event in the videos, it samples 1–2 representative frames at fractional intervals between the start and end timestamps and saves them as JPEG images. Captions associated with each event are paired with the extracted frames, and all metadata—such as video name, category, and frame index—is recorded. The final output is a CSV file containing all image paths and their captions (test_image_captions.csv) and a folder of extracted frames (output_frames). The notebook concludes by packaging this data into a structured Kaggle dataset and uploading it using the Kaggle API. This processed dataset is valuable for video-language modeling tasks.

# %%
import os
import cv2
import json
import re
import pandas as pd
from collections import defaultdict

# Parameters
ANNOTATION_FILES = [
    '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Train.json',
    '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Test.json',
    '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Val.json'
]
VIDEOS_DIR            = '/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos'
OUTPUT_DIR            = 'output_frames'
CSV_FILE              = 'test_image_captions.csv'
VIDEO_EXTENSIONS      = ['.mp4', '.avi', '.mov', '.mkv']
DEFAULT_MAX_PER_CAT   = 150
NORMAL_MAX_PER_CAT    = 400
FRAMES_PER_CAPTION    = 2  # Set to 1 or 2

# Helpers
def find_video_file(name, base_dir, exts):
    for root, _, files in os.walk(base_dir):
        for file in files:
            n, ext = os.path.splitext(file)
            if n == name and ext.lower() in exts:
                return os.path.join(root, file)
    return None

def extract_category_from_key(key):
    m = re.match(r'([A-Za-z]+)', key)
    return m.group(1) if m else 'Unknown'

# Create output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load and merge annotations
annotations = {}
for fpath in ANNOTATION_FILES:
    with open(fpath, 'r') as f:
        annotations.update(json.load(f))

# Function: sample frames per timestamp interval
def extract_frames_from_timestamps(video_path, video_name, category, timestamps, sentences):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    entries = []

    for idx, ((start_t, end_t), sentence) in enumerate(zip(timestamps, sentences)):
        if end_t <= start_t:
            continue
        # Determine sample fractions for 1 or 2 frames
        if FRAMES_PER_CAPTION == 1:
            fractions = [0.5]
        else:
            fractions = [0.25, 0.75]

        for frac in fractions:
            ts = start_t + frac * (end_t - start_t)
            frame_idx = int(ts * fps)
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
            ret, frame = cap.read()
            if not ret:
                continue

            fname = f"{video_name}_cap{idx}_frame{frame_idx}.jpg"
            path  = os.path.join(OUTPUT_DIR, fname)
            cv2.imwrite(path, frame)
            entries.append({
                'image_path':  path,
                'caption':     sentence,
                'video_key':   video_name,
                'category':    category,
                'frame_index': frame_idx
            })

    cap.release()
    return entries

# Main loop
category_counts = defaultdict(int)
all_entries = []

for vid_key, data in annotations.items():
    cat = extract_category_from_key(vid_key)
    limit = NORMAL_MAX_PER_CAT if cat.lower() == 'normal' else DEFAULT_MAX_PER_CAT
    if category_counts[cat] >= limit:
        continue

    video_file = find_video_file(vid_key, VIDEOS_DIR, VIDEO_EXTENSIONS)
    if not video_file:
        print(f"[WARNING] Missing file for {vid_key}")
        continue

    timestamps = data.get('timestamps', [])
    sentences  = data.get('sentences', [])
    if not timestamps or not sentences:
        continue

    print(f"Processing {vid_key} ({cat})...")
    entries = extract_frames_from_timestamps(
        video_path=video_file,
        video_name=vid_key,
        category=cat,
        timestamps=timestamps,
        sentences=sentences
    )

    all_entries.extend(entries)
    category_counts[cat] += 1
    if category_counts[cat] == limit:
        print(f"Reached {limit} videos for category '{cat}'")

# Save CSV
df = pd.DataFrame(all_entries)
df.to_csv(CSV_FILE, index=False)
print(f"Saved {len(df)} frames to {CSV_FILE}")
# Out:
# Processing Abuse001_x264 (Abuse)...
# Processing Abuse002_x264 (Abuse)...
# Processing Abuse003_x264 (Abuse)...
# Processing Abuse004_x264 (Abuse)...
# Processing Abuse005_x264 (Abuse)...
# Processing Abuse006_x264 (Abuse)...
# Processing Abuse007_x264 (Abuse)...
# Processing Abuse008_x264 (Abuse)...
# Processing Abuse009_x264 (Abuse)...
# Processing Abuse010_x264 (Abuse)...
# Processing Abuse011_x264 (Abuse)...
# Processing Abuse012_x264 (Abuse)...
# Processing Abuse013_x264 (Abuse)...
# Processing Abuse014_x264 (Abuse)...
# Processing Abuse015_x264 (Abuse)...
# Processing Abuse016_x264 (Abuse)...
# Processing Abuse017_x264 (Abuse)...
# Processing Abuse018_x264 (Abuse)...
# Processing Abuse019_x264 (Abuse)...
# Processing Abuse020_x264 (Abuse)...
# Processing Abuse021_x264 (Abuse)...
# Processing Abuse022_x264 (Abuse)...
# Processing Abuse023_x264 (Abuse)...
# Processing Abuse024_x264 (Abuse)...
# Processing Abuse025_x264 (Abuse)...
# Processing Abuse026_x264 (Abuse)...
# Processing Abuse027_x264 (Abuse)...
# Processing Abuse028_x264 (Abuse)...
# Processing Abuse029_x264 (Abuse)...
# Processing Abuse030_x264 (Abuse)...
# Processing Abuse031_x264 (Abuse)...
# Processing Abuse032_x264 (Abuse)...
# Processing Abuse033_x264 (Abuse)...
# Processing Abuse034_x264 (Abuse)...
# Processing Abuse035_x264 (Abuse)...
# Processing Abuse036_x264 (Abuse)...
# Processing Arrest001_x264 (Arrest)...
# Processing Arrest002_x264 (Arrest)...
# Processing Arrest003_x264 (Arrest)...
# Processing Arrest004_x264 (Arrest)...
# Processing Arrest005_x264 (Arrest)...
# Processing Arrest006_x264 (Arrest)...
# Processing Arrest007_x264 (Arrest)...
# Processing Arrest008_x264 (Arrest)...
# Processing Arrest009_x264 (Arrest)...
# Processing Arrest010_x264 (Arrest)...
# Processing Arrest011_x264 (Arrest)...
# Processing Arrest012_x264 (Arrest)...
# Processing Arrest013_x264 (Arrest)...
# Processing Arrest014_x264 (Arrest)...
# Processing Arrest015_x264 (Arrest)...
# Processing Arrest016_x264 (Arrest)...
# Processing Arrest017_x264 (Arrest)...
# Processing Arrest018_x264 (Arrest)...
# Processing Arrest019_x264 (Arrest)...
# Processing Arrest020_x264 (Arrest)...
# Processing Arrest021_x264 (Arrest)...
# Processing Arrest022_x264 (Arrest)...
# Processing Shoplifting029_x264 (Shoplifting)...
# Processing Shoplifting030_x264 (Shoplifting)...
# Processing Shoplifting031_x264 (Shoplifting)...
# Processing Shoplifting032_x264 (Shoplifting)...
# Processing Shoplifting033_x264 (Shoplifting)...
# Processing Stealing002_x264 (Stealing)...
# Processing Stealing003_x264 (Stealing)...
# Processing Stealing004_x264 (Stealing)...
# Processing Stealing006_x264 (Stealing)...
# Processing Stealing007_x264 (Stealing)...
# Processing Stealing008_x264 (Stealing)...
# Processing Stealing009_x264 (Stealing)...
# Processing Stealing010_x264 (Stealing)...
# Processing Stealing011_x264 (Stealing)...
# Processing Stealing012_x264 (Stealing)...
# Processing Stealing013_x264 (Stealing)...
# Processing Stealing014_x264 (Stealing)...
# Processing Stealing015_x264 (Stealing)...
# Processing Stealing016_x264 (Stealing)...
# Processing Stealing017_x264 (Stealing)...
# Processing Stealing018_x264 (Stealing)...
# Processing Stealing019_x264 (Stealing)...
# Processing Stealing020_x264 (Stealing)...
# Processing Stealing021_x264 (Stealing)...
# Processing Stealing022_x264 (Stealing)...
# Processing Stealing023_x264 (Stealing)...
# Processing Stealing024_x264 (Stealing)...
# Processing Stealing025_x264 (Stealing)...
# Processing Stealing026_x264 (Stealing)...
# Processing Stealing027_x264 (Stealing)...
# Processing Stealing028_x264 (Stealing)...
# Processing Stealing029_x264 (Stealing)...
# Processing Stealing030_x264 (Stealing)...
# Processing Stealing031_x264 (Stealing)...
# Processing Stealing032_x264 (Stealing)...
# Processing Stealing035_x264 (Stealing)...
# Processing Stealing036_x264 (Stealing)...
# Processing Stealing037_x264 (Stealing)...
# Processing Stealing042_x264 (Stealing)...
# Processing Stealing043_x264 (Stealing)...
# Processing Stealing044_x264 (Stealing)...
# Processing Stealing045_x264 (Stealing)...
# Processing Stealing046_x264 (Stealing)...
# Processing Stealing047_x264 (Stealing)...
# Processing Stealing048_x264 (Stealing)...
# Processing Stealing049_x264 (Stealing)...
# Processing Stealing050_x264 (Stealing)...
# Processing Stealing051_x264 (Stealing)...
# Processing Stealing052_x264 (Stealing)...
# Processing Stealing053_x264 (Stealing)...
# Processing Stealing054_x264 (Stealing)...
# Processing Stealing055_x264 (Stealing)...
# Processing Stealing057_x264 (Stealing)...
# Processing Stealing058_x264 (Stealing)...
# Processing Stealing059_x264 (Stealing)...
# Processing Stealing060_x264 (Stealing)...
# Processing Stealing061_x264 (Stealing)...
# Processing Stealing062_x264 (Stealing)...
# Processing Stealing063_x264 (Stealing)...
# Processing Stealing065_x264 (Stealing)...
# Processing Stealing066_x264 (Stealing)...
# Processing Stealing067_x264 (Stealing)...
# Processing Stealing068_x264 (Stealing)...
# Processing Stealing069_x264 (Stealing)...
# Processing Stealing070_x264 (Stealing)...
# Processing Stealing071_x264 (Stealing)...
# Processing Stealing072_x264 (Stealing)...
# Processing Stealing073_x264 (Stealing)...
# Processing Stealing074_x264 (Stealing)...
# Processing Stealing075_x264 (Stealing)...
# Processing Stealing077_x264 (Stealing)...
# Processing Vandalism001_x264 (Vandalism)...
# Processing Vandalism002_x264 (Vandalism)...
# Processing Stealing084_x264 (Stealing)...
# Processing Stealing086_x264 (Stealing)...
# Processing Stealing087_x264 (Stealing)...
# Processing Stealing088_x264 (Stealing)...
# Processing Stealing089_x264 (Stealing)...
# Processing Stealing091_x264 (Stealing)...
# Processing Stealing092_x264 (Stealing)...
# Processing Vandalism031_x264 (Vandalism)...
# Processing Vandalism032_x264 (Vandalism)...
# Processing Vandalism033_x264 (Vandalism)...
# Processing Vandalism034_x264 (Vandalism)...
# Processing Vandalism035_x264 (Vandalism)...
# Processing Vandalism036_x264 (Vandalism)...
# Processing Vandalism038_x264 (Vandalism)...
# Processing Vandalism039_x264 (Vandalism)...
# Processing Vandalism040_x264 (Vandalism)...
# Processing Vandalism041_x264 (Vandalism)...
# Processing Vandalism042_x264 (Vandalism)...
# Processing Vandalism043_x264 (Vandalism)...
# Processing Abuse043_x264 (Abuse)...
# Processing Abuse044_x264 (Abuse)...
# Processing Abuse045_x264 (Abuse)...
# Processing Abuse046_x264 (Abuse)...
# Processing Abuse047_x264 (Abuse)...
# Processing Abuse048_x264 (Abuse)...
# Processing Abuse049_x264 (Abuse)...
# Processing Abuse050_x264 (Abuse)...
# Processing Arrest047_x264 (Arrest)...
# Processing Arson040_x264 (Arson)...
# Processing Arson041_x264 (Arson)...
# Processing Arson042_x264 (Arson)...
# Processing Arson044_x264 (Arson)...
# Processing Arson045_x264 (Arson)...
# Processing Arson046_x264 (Arson)...
# Processing Arson047_x264 (Arson)...
# Processing Arson048_x264 (Arson)...
# Processing Arson049_x264 (Arson)...
# Processing Arson050_x264 (Arson)...
# Processing Arson051_x264 (Arson)...
# Processing Arson052_x264 (Arson)...
# Processing Arson053_x264 (Arson)...
# Processing Assault041_x264 (Assault)...
# Processing Assault042_x264 (Assault)...
# Processing Assault044_x264 (Assault)...
# Processing Assault047_x264 (Assault)...
# Processing Assault048_x264 (Assault)...
# Processing Assault049_x264 (Assault)...
# Processing Assault050_x264 (Assault)...
# Processing Assault051_x264 (Assault)...
# Processing Assault052_x264 (Assault)...
# Processing Burglary088_x264 (Burglary)...
# Processing Burglary089_x264 (Burglary)...
# Processing Burglary090_x264 (Burglary)...
# Processing Burglary091_x264 (Burglary)...
# Processing Burglary092_x264 (Burglary)...
# Processing Burglary093_x264 (Burglary)...
# Processing Burglary094_x264 (Burglary)...
# Processing Burglary095_x264 (Burglary)...
# Processing Burglary096_x264 (Burglary)...
# Processing Burglary097_x264 (Burglary)...
# Processing Burglary098_x264 (Burglary)...
# Processing Burglary099_x264 (Burglary)...
# Processing Burglary100_x264 (Burglary)...
# Processing Explosion030_x264 (Explosion)...
# Processing Explosion032_x264 (Explosion)...
# Processing Explosion033_x264 (Explosion)...
# Processing Explosion034_x264 (Explosion)...
# Processing Explosion035_x264 (Explosion)...
# Processing Explosion036_x264 (Explosion)...
# Processing Explosion037_x264 (Explosion)...
# Processing Explosion038_x264 (Explosion)...
# Processing Explosion039_x264 (Explosion)...
# Processing Explosion040_x264 (Explosion)...
# Processing Explosion041_x264 (Explosion)...
# Processing Explosion042_x264 (Explosion)...
# Processing Explosion043_x264 (Explosion)...
# Processing Shoplifting050_x264 (Shoplifting)...
# Processing Shoplifting051_x264 (Shoplifting)...
# Processing Shoplifting052_x264 (Shoplifting)...
# Processing Shoplifting053_x264 (Shoplifting)...
# Processing Shoplifting054_x264 (Shoplifting)...
# Processing Shoplifting055_x264 (Shoplifting)...
# Processing Stealing093_x264 (Stealing)...
# Processing Stealing094_x264 (Stealing)...
# Processing Stealing095_x264 (Stealing)...
# Processing Stealing096_x264 (Stealing)...
# Processing Stealing097_x264 (Stealing)...
# Processing Stealing098_x264 (Stealing)...
# Processing Stealing100_x264 (Stealing)...
# Processing Stealing101_x264 (Stealing)...
# Processing Stealing102_x264 (Stealing)...
# Processing Stealing103_x264 (Stealing)...
# Processing Stealing104_x264 (Stealing)...
# Processing Stealing105_x264 (Stealing)...
# Processing Stealing106_x264 (Stealing)...
# Processing Stealing107_x264 (Stealing)...
# Processing Stealing108_x264 (Stealing)...
# Processing Stealing109_x264 (Stealing)...
# Processing Stealing110_x264 (Stealing)...
# Processing Stealing111_x264 (Stealing)...
# Processing Stealing112_x264 (Stealing)...
# Processing Stealing113_x264 (Stealing)...
# Processing Stealing114_x264 (Stealing)...
# Processing Vandalism044_x264 (Vandalism)...
# Processing Vandalism045_x264 (Vandalism)...
# Processing Vandalism046_x264 (Vandalism)...
# Processing Vandalism047_x264 (Vandalism)...
# Processing Vandalism048_x264 (Vandalism)...
# Processing Vandalism049_x264 (Vandalism)...
# Processing Vandalism050_x264 (Vandalism)...
# Saved 29310 frames to test_image_captions.csv

# %%
df
# Out:
#                                               image_path  \
# 0           output_frames/Abuse001_x264_cap0_frame39.jpg
# 1          output_frames/Abuse001_x264_cap0_frame119.jpg
# 2          output_frames/Abuse001_x264_cap1_frame221.jpg
# 3          output_frames/Abuse001_x264_cap1_frame243.jpg
# 4          output_frames/Abuse001_x264_cap2_frame225.jpg
# ...                                                  ...
# 29305  output_frames/Vandalism050_x264_cap0_frame180.jpg
# 29306  output_frames/Vandalism050_x264_cap1_frame318.jpg
# 29307  output_frames/Vandalism050_x264_cap1_frame476.jpg
# 29308  output_frames/Vandalism050_x264_cap2_frame641.jpg
# 29309  output_frames/Vandalism050_x264_cap2_frame813.jpg
#
#                                                  caption          video_key  \
# 0      A woman with short hair, slightly fat, wearing...      Abuse001_x264
# 1      A woman with short hair, slightly fat, wearing...      Abuse001_x264
# 2      A man wearing a white shirt and black pants en...      Abuse001_x264
# 3      A man wearing a white shirt and black pants en...      Abuse001_x264
# 4      A man wearing a black shirt and black pants en...      Abuse001_x264
# ...                                                  ...                ...
# 29305  There are three people next to a black car and...  Vandalism050_x264
# 29306  A man in gray clothes with a hat poured someth...  Vandalism050_x264
# 29307  A man in gray clothes with a hat poured someth...  Vandalism050_x264
# 29308  The man in white pants next to the black car p...  Vandalism050_x264
# 29309  The man in white pants next to the black car p...  Vandalism050_x264
#
#         category  frame_index
# 0          Abuse           39
# 1          Abuse          119
# 2          Abuse          221
# 3          Abuse          243
# 4          Abuse          225
# ...          ...          ...
# 29305  Vandalism          180
# 29306  Vandalism          318
# 29307  Vandalism          476
# 29308  Vandalism          641
# 29309  Vandalism          813
#
# [29310 rows x 5 columns]

# %%
# !rm -rf test_output_frames

# %%
# !pip install kaggle --quiet

# %%
# %%bash
# # 1) Create your Kaggle API key file
# mkdir -p ~/.kaggle
# cat > ~/.kaggle/kaggle.json <<EOF
# {
#   "username":"nourfakih",
#   "key":"0005ac45aa3dc353c01a5d486ed0a5ac"
# }
# EOF
# chmod 600 ~/.kaggle/kaggle.json
# echo "✅ ~/.kaggle/kaggle.json created"
# Out:
# ✅ ~/.kaggle/kaggle.json created

# %%
# in a notebook cell, once you’ve uploaded kaggle.json via the UI
# !mkdir -p /root/.kaggle
# !cp kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# 2) Generate dataset-metadata.json inside your output directory
import os, json

OUTPUT_DIR = '/kaggle/working/'
os.makedirs(OUTPUT_DIR, exist_ok=True)

metadata = {
    "title":       "UCF-Crime Frame+Caption Extractions",
    "id":          "nourfakih/ucf-crime-extracted-frames",
    "subtitle":    "Frames sampled at each annotation timestamp with captions",
    "description": "This dataset contains JPEGs extracted per annotation timestamp from UCF-Crime videos, along with a CSV of matching captions.",
    "licenses": [
        {"name": "CC0-1.0"}
    ]
}

with open(os.path.join(OUTPUT_DIR, 'dataset-metadata.json'), 'w') as f:
    json.dump(metadata, f, indent=2)

print(f"✅ {os.path.join(OUTPUT_DIR,'dataset-metadata.json')} written")
# Out:
# ✅ /kaggle/working/dataset-metadata.json written

# %%
metadata = {
    "title": "UCF-Crime Extracted Frames & Captions",
    "id": "nourfakih/ucf-crime-frames-captions",
    "subtitle": "Frames with timestamp-aligned captions",
    "description": "This dataset contains frames extracted from the UCF-Crime dataset, each matched to timestamped captions. Useful for video-language tasks.",
    "licenses": [{"name": "CC0-1.0"}]
}

with open('/kaggle/working/dataset-metadata.json', 'w') as f:
    json.dump(metadata, f, indent=4)

# %%
# !kaggle datasets init -p /kaggle/working
# Out:
# Data package template written to: /kaggle/working/dataset-metadata.json

# %%
# !kaggle datasets create -p  /kaggle/working
# Out:
# Default slug detected, please change values before uploading

# %%
# !kaggle datasets create -p /kaggle/working
# Out:
# Skipping folder: .virtual_documents; use '--dir-mode' to upload folders
# Starting upload for file test_image_captions.csv
# 100%|██████████████████████████████████████| 5.00M/5.00M [00:01<00:00, 4.16MB/s]
# Upload successful: test_image_captions.csv (5MB)
# Skipping folder: output_frames; use '--dir-mode' to upload folders
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/nourfakih/ucf-crime-frames-captions

# %%
# !kaggle datasets create -p /kaggle/working --dir-mode zip
# Out:
# Starting upload for file .virtual_documents.zip
# 100%|█████████████████████████████████████████| 22.0/22.0 [00:00<00:00, 63.7B/s]
# Upload successful: .virtual_documents.zip (22B)
# Starting upload for file test_image_captions.csv
# Error while trying to load upload info: ApiStartBlobUploadRequest.__init__() got an unexpected keyword argument 'type'
# 100%|██████████████████████████████████████| 5.00M/5.00M [00:01<00:00, 4.13MB/s]
# Upload successful: test_image_captions.csv (5MB)
# Starting upload for file output_frames.zip
# 100%|████████████████████████████████████████| 845M/845M [00:21<00:00, 41.3MB/s]
# Upload successful: output_frames.zip (845MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/nourfakih/ucf-crime-extracted-frames
